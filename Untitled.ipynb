# %%
# %matplotlib inline
import pycamhd as camhd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(12, 12))

import cython_lazyquicktime.lazyqt as lazyqt

# %%
filename = b'/data/CAMHDA301-20160506T000000Z.mov'
frame_number = 7200
# Out:
#   File "<ipython-input-28-a04e1ffb28c4>", line 4
#     %%time
#     ^
# SyntaxError: invalid syntax

# %%
# %%time
info = lazyqt.movie_info(filename)
print(info)
# Out:
# {'duration': 839.4719848632812, 'num_frames': 25159, 'valid': True}
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 1.39 ms

# %%
# %%time
frame = lazyqt.get_frame(filename, frame_number)
# Out:
# CPU times: user 188 ms, sys: 4 ms, total: 192 ms
# Wall time: 221 ms

# %%
# %%time
frame = camhd.get_frame(filename, frame_num, 'rgb24')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>()
#
# AttributeError: module 'pycamhd' has no attribute 'get_frame'

# %%
imgplot = plt.imshow(frame)
