# %% [markdown]
# Running Jupyter and the [lazyqt_demo_notebooks](https://github.com/CamHD-Analysis/lazyqt_demo_notebooks) on a Google Compute Engine instance.   Machine is _n1-highcpu-4 (4 vCPUs, 3.6 GB memory)_ running Ubuntu 16.04LTS.   Manually installed Miniconda, and from there installed Jupyter and dependencies.
#
# Ran the last block from [Lazycache Benchmarking](https://github.com/CamHD-Analysis/lazyqt_demo_notebooks/blob/master/Lazycache%20Benchmarking.ipynb) repeatedly to warm the cache.  Got variable results as I continued to hit the cache.  Unfortunately, no amazing results even "across the datacenter" between the two instances.
#
# As with other data sets, results are the mean wall clock time to retrieve a random frame from one video.   The randomizer is seeded consistently so results are repeated.   These tests used a different random seed from previous testing.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(9, 9))

# %%
data = pd.Series([2684.393597,503.570867,246.178055,237.999845,193.861699,178.219604,160.611200,151.524568,222.419190,185.088372,162.946749,147.112799,221.965265,140.543318])

# %%
plt = data.plot()
plt.set_xlabel( 'iteration' )
plt.set_ylabel( 'mean time per frame (ms)' )
